# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')
import re
from nltk.corpus import stopwords
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
zomato_real=pd.read_csv('C:/Users/mohdm/Downloads/archive/zomato.csv')
zomato_real.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari
# 3          Buffet    Banashankari
# 4          Buffet    Banashankari

# %%
zomato=zomato_real.drop(['url','dish_liked','phone'],axis=1)

# %%
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes                    location  \
# 0            Yes   4.1/5    775                Banashankari
# 1             No   4.1/5    787                Banashankari
# 2             No   3.8/5    918                Banashankari
# 3             No   3.7/5     88                Banashankari
# 4             No   3.8/5    166                Basavanagudi
# ...          ...     ...    ...                         ...
# 51712         No  3.6 /5     27                  Whitefield
# 51713         No     NaN      0                  Whitefield
# 51714         No     NaN      0                  Whitefield
# 51715        Yes  4.3 /5    236  ITPL Main Road, Whitefield
# 51716         No  3.4 /5     13  ITPL Main Road, Whitefield
#
#                  rest_type                                cuisines  \
# 0            Casual Dining          North Indian, Mughlai, Chinese
# 1            Casual Dining             Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                  Cafe, Mexican, Italian
# 3              Quick Bites              South Indian, North Indian
# 4            Casual Dining                North Indian, Rajasthani
# ...                    ...                                     ...
# 51712                  Bar                             Continental
# 51713                  Bar                             Finger Food
# 51714                  Bar                             Finger Food
# 51715                  Bar                             Finger Food
# 51716   Bar, Casual Dining  Finger Food, North Indian, Continental
#
#       approx_cost(for two people)  \
# 0                             800
# 1                             800
# 2                             800
# 3                             300
# 4                             600
# ...                           ...
# 51712                       1,500
# 51713                         600
# 51714                       2,000
# 51715                       2,500
# 51716                       1,500
#
#                                             reviews_list menu_item  \
# 0      [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1      [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2      [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3      [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4      [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...                                                  ...       ...
# 51712  [('Rated 5.0', "RATED\n  Food and service are ...        []
# 51713                                                 []        []
# 51714                                                 []        []
# 51715  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
# 51716  [('Rated 5.0', 'RATED\n  Great ambience , look...        []
#
#       listed_in(type) listed_in(city)
# 0              Buffet    Banashankari
# 1              Buffet    Banashankari
# 2              Buffet    Banashankari
# 3              Buffet    Banashankari
# 4              Buffet    Banashankari
# ...               ...             ...
# 51712   Pubs and bars      Whitefield
# 51713   Pubs and bars      Whitefield
# 51714   Pubs and bars      Whitefield
# 51715   Pubs and bars      Whitefield
# 51716   Pubs and bars      Whitefield
#
# [51717 rows x 14 columns]

# %%
zomato.duplicated().sum()
zomato.drop_duplicates(inplace=True)
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes                    location  \
# 0            Yes   4.1/5    775                Banashankari
# 1             No   4.1/5    787                Banashankari
# 2             No   3.8/5    918                Banashankari
# 3             No   3.7/5     88                Banashankari
# 4             No   3.8/5    166                Basavanagudi
# ...          ...     ...    ...                         ...
# 51712         No  3.6 /5     27                  Whitefield
# 51713         No     NaN      0                  Whitefield
# 51714         No     NaN      0                  Whitefield
# 51715        Yes  4.3 /5    236  ITPL Main Road, Whitefield
# 51716         No  3.4 /5     13  ITPL Main Road, Whitefield
#
#                  rest_type                                cuisines  \
# 0            Casual Dining          North Indian, Mughlai, Chinese
# 1            Casual Dining             Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                  Cafe, Mexican, Italian
# 3              Quick Bites              South Indian, North Indian
# 4            Casual Dining                North Indian, Rajasthani
# ...                    ...                                     ...
# 51712                  Bar                             Continental
# 51713                  Bar                             Finger Food
# 51714                  Bar                             Finger Food
# 51715                  Bar                             Finger Food
# 51716   Bar, Casual Dining  Finger Food, North Indian, Continental
#
#       approx_cost(for two people)  \
# 0                             800
# 1                             800
# 2                             800
# 3                             300
# 4                             600
# ...                           ...
# 51712                       1,500
# 51713                         600
# 51714                       2,000
# 51715                       2,500
# 51716                       1,500
#
#                                             reviews_list menu_item  \
# 0      [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1      [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2      [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3      [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4      [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...                                                  ...       ...
# 51712  [('Rated 5.0', "RATED\n  Food and service are ...        []
# 51713                                                 []        []
# 51714                                                 []        []
# 51715  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
# 51716  [('Rated 5.0', 'RATED\n  Great ambience , look...        []
#
#       listed_in(type) listed_in(city)
# 0              Buffet    Banashankari
# 1              Buffet    Banashankari
# 2              Buffet    Banashankari
# 3              Buffet    Banashankari
# 4              Buffet    Banashankari
# ...               ...             ...
# 51712   Pubs and bars      Whitefield
# 51713   Pubs and bars      Whitefield
# 51714   Pubs and bars      Whitefield
# 51715   Pubs and bars      Whitefield
# 51716   Pubs and bars      Whitefield
#
# [51674 rows x 14 columns]

# %%
zomato.isnull().sum()
zomato.dropna(how='any',inplace=True)
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51709                         The Farm House Bar n Grill           No
# 51711                                            Bhagini           No
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes                    location  \
# 0            Yes   4.1/5    775                Banashankari
# 1             No   4.1/5    787                Banashankari
# 2             No   3.8/5    918                Banashankari
# 3             No   3.7/5     88                Banashankari
# 4             No   3.8/5    166                Basavanagudi
# ...          ...     ...    ...                         ...
# 51709         No  3.7 /5     34                  Whitefield
# 51711         No  2.5 /5     81                  Whitefield
# 51712         No  3.6 /5     27                  Whitefield
# 51715        Yes  4.3 /5    236  ITPL Main Road, Whitefield
# 51716         No  3.4 /5     13  ITPL Main Road, Whitefield
#
#                  rest_type                                     cuisines  \
# 0            Casual Dining               North Indian, Mughlai, Chinese
# 1            Casual Dining                  Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                       Cafe, Mexican, Italian
# 3              Quick Bites                   South Indian, North Indian
# 4            Casual Dining                     North Indian, Rajasthani
# ...                    ...                                          ...
# 51709   Casual Dining, Bar                    North Indian, Continental
# 51711   Casual Dining, Bar  Andhra, South Indian, Chinese, North Indian
# 51712                  Bar                                  Continental
# 51715                  Bar                                  Finger Food
# 51716   Bar, Casual Dining       Finger Food, North Indian, Continental
#
#       approx_cost(for two people)  \
# 0                             800
# 1                             800
# 2                             800
# 3                             300
# 4                             600
# ...                           ...
# 51709                         800
# 51711                         800
# 51712                       1,500
# 51715                       2,500
# 51716                       1,500
#
#                                             reviews_list menu_item  \
# 0      [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1      [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2      [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3      [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4      [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...                                                  ...       ...
# 51709  [('Rated 4.0', 'RATED\n  Ambience- Big and spa...        []
# 51711  [('Rated 4.0', 'RATED\n  A fine place to chill...        []
# 51712  [('Rated 5.0', "RATED\n  Food and service are ...        []
# 51715  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
# 51716  [('Rated 5.0', 'RATED\n  Great ambience , look...        []
#
#       listed_in(type) listed_in(city)
# 0              Buffet    Banashankari
# 1              Buffet    Banashankari
# 2              Buffet    Banashankari
# 3              Buffet    Banashankari
# 4              Buffet    Banashankari
# ...               ...             ...
# 51709   Pubs and bars      Whitefield
# 51711   Pubs and bars      Whitefield
# 51712   Pubs and bars      Whitefield
# 51715   Pubs and bars      Whitefield
# 51716   Pubs and bars      Whitefield
#
# [43499 rows x 14 columns]

# %%
zomato = zomato.rename(columns={'approx_cost(for two people)':'cost','listed_in(type)':'type', 'listed_in(city)':'city'})
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51709                         The Farm House Bar n Grill           No
# 51711                                            Bhagini           No
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes                    location  \
# 0            Yes   4.1/5    775                Banashankari
# 1             No   4.1/5    787                Banashankari
# 2             No   3.8/5    918                Banashankari
# 3             No   3.7/5     88                Banashankari
# 4             No   3.8/5    166                Basavanagudi
# ...          ...     ...    ...                         ...
# 51709         No  3.7 /5     34                  Whitefield
# 51711         No  2.5 /5     81                  Whitefield
# 51712         No  3.6 /5     27                  Whitefield
# 51715        Yes  4.3 /5    236  ITPL Main Road, Whitefield
# 51716         No  3.4 /5     13  ITPL Main Road, Whitefield
#
#                  rest_type                                     cuisines  \
# 0            Casual Dining               North Indian, Mughlai, Chinese
# 1            Casual Dining                  Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                       Cafe, Mexican, Italian
# 3              Quick Bites                   South Indian, North Indian
# 4            Casual Dining                     North Indian, Rajasthani
# ...                    ...                                          ...
# 51709   Casual Dining, Bar                    North Indian, Continental
# 51711   Casual Dining, Bar  Andhra, South Indian, Chinese, North Indian
# 51712                  Bar                                  Continental
# 51715                  Bar                                  Finger Food
# 51716   Bar, Casual Dining       Finger Food, North Indian, Continental
#
#         cost                                       reviews_list menu_item  \
# 0        800  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1        800  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2        800  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3        300  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4        600  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...      ...                                                ...       ...
# 51709    800  [('Rated 4.0', 'RATED\n  Ambience- Big and spa...        []
# 51711    800  [('Rated 4.0', 'RATED\n  A fine place to chill...        []
# 51712  1,500  [('Rated 5.0', "RATED\n  Food and service are ...        []
# 51715  2,500  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
# 51716  1,500  [('Rated 5.0', 'RATED\n  Great ambience , look...        []
#
#                 type          city
# 0             Buffet  Banashankari
# 1             Buffet  Banashankari
# 2             Buffet  Banashankari
# 3             Buffet  Banashankari
# 4             Buffet  Banashankari
# ...              ...           ...
# 51709  Pubs and bars    Whitefield
# 51711  Pubs and bars    Whitefield
# 51712  Pubs and bars    Whitefield
# 51715  Pubs and bars    Whitefield
# 51716  Pubs and bars    Whitefield
#
# [43499 rows x 14 columns]

# %%
zomato['cost'] = zomato['cost'].astype(str) #Changing the cost to string
zomato['cost'] = zomato['cost'].apply(lambda x: x.replace(',','.')) #Using lambda function to replace ',' from cost
zomato['cost'] = zomato['cost'].astype(float)
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51709                         The Farm House Bar n Grill           No
# 51711                                            Bhagini           No
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes                    location  \
# 0            Yes   4.1/5    775                Banashankari
# 1             No   4.1/5    787                Banashankari
# 2             No   3.8/5    918                Banashankari
# 3             No   3.7/5     88                Banashankari
# 4             No   3.8/5    166                Basavanagudi
# ...          ...     ...    ...                         ...
# 51709         No  3.7 /5     34                  Whitefield
# 51711         No  2.5 /5     81                  Whitefield
# 51712         No  3.6 /5     27                  Whitefield
# 51715        Yes  4.3 /5    236  ITPL Main Road, Whitefield
# 51716         No  3.4 /5     13  ITPL Main Road, Whitefield
#
#                  rest_type                                     cuisines  \
# 0            Casual Dining               North Indian, Mughlai, Chinese
# 1            Casual Dining                  Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                       Cafe, Mexican, Italian
# 3              Quick Bites                   South Indian, North Indian
# 4            Casual Dining                     North Indian, Rajasthani
# ...                    ...                                          ...
# 51709   Casual Dining, Bar                    North Indian, Continental
# 51711   Casual Dining, Bar  Andhra, South Indian, Chinese, North Indian
# 51712                  Bar                                  Continental
# 51715                  Bar                                  Finger Food
# 51716   Bar, Casual Dining       Finger Food, North Indian, Continental
#
#         cost                                       reviews_list menu_item  \
# 0      800.0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1      800.0  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2      800.0  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3      300.0  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4      600.0  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...      ...                                                ...       ...
# 51709  800.0  [('Rated 4.0', 'RATED\n  Ambience- Big and spa...        []
# 51711  800.0  [('Rated 4.0', 'RATED\n  A fine place to chill...        []
# 51712    1.5  [('Rated 5.0', "RATED\n  Food and service are ...        []
# 51715    2.5  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
# 51716    1.5  [('Rated 5.0', 'RATED\n  Great ambience , look...        []
#
#                 type          city
# 0             Buffet  Banashankari
# 1             Buffet  Banashankari
# 2             Buffet  Banashankari
# 3             Buffet  Banashankari
# 4             Buffet  Banashankari
# ...              ...           ...
# 51709  Pubs and bars    Whitefield
# 51711  Pubs and bars    Whitefield
# 51712  Pubs and bars    Whitefield
# 51715  Pubs and bars    Whitefield
# 51716  Pubs and bars    Whitefield
#
# [43499 rows x 14 columns]

# %%
zomato = zomato.loc[zomato.rate !='NEW']
zomato = zomato.loc[zomato.rate !='-'].reset_index(drop=True)
remove_slash = lambda x: x.replace('/5', '') if type(x) == .str else x
zomato.rate = zomato.rate.apply(remove_slash).str.strip().astype('float')
# Out:
#   Cell In[57], line 3
#     remove_slash = lambda x: x.replace('/5', '') if type(x) == .str else x
#                              ^
# SyntaxError: expected 'else' after 'if' expression

# %%
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 41232  136, SAP Labs India, KIADB Export Promotion In...
# 41233  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 41234  Four Points by Sheraton Bengaluru, 43/3, White...
# 41235  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 41236  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# 2                                        San Churro Cafe          True
# 3                                  Addhuri Udupi Bhojana         False
# 4                                          Grand Village         False
# ...                                                  ...           ...
# 41232                         The Farm House Bar N Grill         False
# 41233                                            Bhagini         False
# 41234  Best Brews - Four Points By Sheraton Bengaluru...         False
# 41235  Chime - Sheraton Grand Bengaluru Whitefield Ho...         False
# 41236                       The Nest - The Den Bengaluru         False
#
#        book_table  rate  votes                    location  \
# 0            True   4.1    775                Banashankari
# 1           False   4.1    787                Banashankari
# 2           False   3.8    918                Banashankari
# 3           False   3.7     88                Banashankari
# 4           False   3.8    166                Basavanagudi
# ...           ...   ...    ...                         ...
# 41232       False   3.7     34                  Whitefield
# 41233       False   2.5     81                  Whitefield
# 41234       False   3.6     27                  Whitefield
# 41235        True   4.3    236  ITPL Main Road, Whitefield
# 41236       False   3.4     13  ITPL Main Road, Whitefield
#
#                  rest_type                                     cuisines  \
# 0            Casual Dining               North Indian, Mughlai, Chinese
# 1            Casual Dining                  Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                       Cafe, Mexican, Italian
# 3              Quick Bites                   South Indian, North Indian
# 4            Casual Dining                     North Indian, Rajasthani
# ...                    ...                                          ...
# 41232   Casual Dining, Bar                    North Indian, Continental
# 41233   Casual Dining, Bar  Andhra, South Indian, Chinese, North Indian
# 41234                  Bar                                  Continental
# 41235                  Bar                                  Finger Food
# 41236   Bar, Casual Dining       Finger Food, North Indian, Continental
#
#         cost                                       reviews_list menu_item  \
# 0      800.0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1      800.0  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2      800.0  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3      300.0  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4      600.0  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...      ...                                                ...       ...
# 41232  800.0  [('Rated 4.0', 'RATED\n  Ambience- Big and spa...        []
# 41233  800.0  [('Rated 4.0', 'RATED\n  A fine place to chill...        []
# 41234    1.5  [('Rated 5.0', "RATED\n  Food and service are ...        []
# 41235    2.5  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
# 41236    1.5  [('Rated 5.0', 'RATED\n  Great ambience , look...        []
#
#                 type          city  Mean Rating
# 0             Buffet  Banashankari     4.118182
# 1             Buffet  Banashankari     4.100000
# 2             Buffet  Banashankari     3.800000
# 3             Buffet  Banashankari     3.700000
# 4             Buffet  Banashankari     3.800000
# ...              ...           ...          ...
# 41232  Pubs and bars    Whitefield     3.700000
# 41233  Pubs and bars    Whitefield     2.283333
# 41234  Pubs and bars    Whitefield     3.600000
# 41235  Pubs and bars    Whitefield     4.300000
# 41236  Pubs and bars    Whitefield     3.400000
#
# [41237 rows x 15 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (1,5))
zomato[['Mean Rating']] = scaler.fit_transform(zomato[['Mean Rating']]).round(2)
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 41232  136, SAP Labs India, KIADB Export Promotion In...
# 41233  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 41234  Four Points by Sheraton Bengaluru, 43/3, White...
# 41235  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 41236  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# 2                                        San Churro Cafe          True
# 3                                  Addhuri Udupi Bhojana         False
# 4                                          Grand Village         False
# ...                                                  ...           ...
# 41232                         The Farm House Bar N Grill         False
# 41233                                            Bhagini         False
# 41234  Best Brews - Four Points By Sheraton Bengaluru...         False
# 41235  Chime - Sheraton Grand Bengaluru Whitefield Ho...         False
# 41236                       The Nest - The Den Bengaluru         False
#
#        book_table  rate  votes                    location  \
# 0            True   4.1    775                Banashankari
# 1           False   4.1    787                Banashankari
# 2           False   3.8    918                Banashankari
# 3           False   3.7     88                Banashankari
# 4           False   3.8    166                Basavanagudi
# ...           ...   ...    ...                         ...
# 41232       False   3.7     34                  Whitefield
# 41233       False   2.5     81                  Whitefield
# 41234       False   3.6     27                  Whitefield
# 41235        True   4.3    236  ITPL Main Road, Whitefield
# 41236       False   3.4     13  ITPL Main Road, Whitefield
#
#                  rest_type                                     cuisines  \
# 0            Casual Dining               North Indian, Mughlai, Chinese
# 1            Casual Dining                  Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                       Cafe, Mexican, Italian
# 3              Quick Bites                   South Indian, North Indian
# 4            Casual Dining                     North Indian, Rajasthani
# ...                    ...                                          ...
# 41232   Casual Dining, Bar                    North Indian, Continental
# 41233   Casual Dining, Bar  Andhra, South Indian, Chinese, North Indian
# 41234                  Bar                                  Continental
# 41235                  Bar                                  Finger Food
# 41236   Bar, Casual Dining       Finger Food, North Indian, Continental
#
#         cost                                       reviews_list menu_item  \
# 0      800.0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1      800.0  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2      800.0  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3      300.0  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4      600.0  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...      ...                                                ...       ...
# 41232  800.0  [('Rated 4.0', 'RATED\n  Ambience- Big and spa...        []
# 41233  800.0  [('Rated 4.0', 'RATED\n  A fine place to chill...        []
# 41234    1.5  [('Rated 5.0', "RATED\n  Food and service are ...        []
# 41235    2.5  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
# 41236    1.5  [('Rated 5.0', 'RATED\n  Great ambience , look...        []
#
#                 type          city  Mean Rating
# 0             Buffet  Banashankari         3.99
# 1             Buffet  Banashankari         3.97
# 2             Buffet  Banashankari         3.58
# 3             Buffet  Banashankari         3.45
# 4             Buffet  Banashankari         3.58
# ...              ...           ...          ...
# 41232  Pubs and bars    Whitefield         3.45
# 41233  Pubs and bars    Whitefield         1.62
# 41234  Pubs and bars    Whitefield         3.32
# 41235  Pubs and bars    Whitefield         4.23
# 41236  Pubs and bars    Whitefield         3.06
#
# [41237 rows x 15 columns]

# %%
zomato["reviews_list"] = zomato["reviews_list"].str.lower()
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 41232  136, SAP Labs India, KIADB Export Promotion In...
# 41233  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 41234  Four Points by Sheraton Bengaluru, 43/3, White...
# 41235  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 41236  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# 2                                        San Churro Cafe          True
# 3                                  Addhuri Udupi Bhojana         False
# 4                                          Grand Village         False
# ...                                                  ...           ...
# 41232                         The Farm House Bar N Grill         False
# 41233                                            Bhagini         False
# 41234  Best Brews - Four Points By Sheraton Bengaluru...         False
# 41235  Chime - Sheraton Grand Bengaluru Whitefield Ho...         False
# 41236                       The Nest - The Den Bengaluru         False
#
#        book_table  rate  votes                    location  \
# 0            True   4.1    775                Banashankari
# 1           False   4.1    787                Banashankari
# 2           False   3.8    918                Banashankari
# 3           False   3.7     88                Banashankari
# 4           False   3.8    166                Basavanagudi
# ...           ...   ...    ...                         ...
# 41232       False   3.7     34                  Whitefield
# 41233       False   2.5     81                  Whitefield
# 41234       False   3.6     27                  Whitefield
# 41235        True   4.3    236  ITPL Main Road, Whitefield
# 41236       False   3.4     13  ITPL Main Road, Whitefield
#
#                  rest_type                                     cuisines  \
# 0            Casual Dining               North Indian, Mughlai, Chinese
# 1            Casual Dining                  Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                       Cafe, Mexican, Italian
# 3              Quick Bites                   South Indian, North Indian
# 4            Casual Dining                     North Indian, Rajasthani
# ...                    ...                                          ...
# 41232   Casual Dining, Bar                    North Indian, Continental
# 41233   Casual Dining, Bar  Andhra, South Indian, Chinese, North Indian
# 41234                  Bar                                  Continental
# 41235                  Bar                                  Finger Food
# 41236   Bar, Casual Dining       Finger Food, North Indian, Continental
#
#         cost                                       reviews_list menu_item  \
# 0      800.0  rated 40 ratedn beautiful place dine inthe int...        []
# 1      800.0  rated 40 ratedn dinner family turned good choo...        []
# 2      800.0  rated 30 ratedn ambience good enough pocket fr...        []
# 3      300.0  rated 40 ratedn great food proper karnataka st...        []
# 4      600.0  rated 40 ratedn good restaurant neighbourhood ...        []
# ...      ...                                                ...       ...
# 41232  800.0  rated 40 ratedn ambience big spacious lawn use...        []
# 41233  800.0  rated 40 ratedn fine place chill office hours ...        []
# 41234    1.5  rated 50 ratedn food service incomparably exce...        []
# 41235    2.5  rated 40 ratedn nice friendly place staff awes...        []
# 41236    1.5  rated 50 ratedn great ambience looking nice go...        []
#
#                 type          city  Mean Rating
# 0             Buffet  Banashankari         3.99
# 1             Buffet  Banashankari         3.97
# 2             Buffet  Banashankari         3.58
# 3             Buffet  Banashankari         3.45
# 4             Buffet  Banashankari         3.58
# ...              ...           ...          ...
# 41232  Pubs and bars    Whitefield         3.45
# 41233  Pubs and bars    Whitefield         1.62
# 41234  Pubs and bars    Whitefield         3.32
# 41235  Pubs and bars    Whitefield         4.23
# 41236  Pubs and bars    Whitefield         3.06
#
# [41237 rows x 15 columns]

# %%
import string
PUNCT_TO_REMOVE = string.punctuation
def remove_punctuation(text):
    """custom function to remove the punctuation"""
    return text.translate(str.maketrans('', '', PUNCT_TO_REMOVE))

zomato["reviews_list"] = zomato["reviews_list"].apply(lambda text: remove_punctuation(text))

# %%
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 41232  136, SAP Labs India, KIADB Export Promotion In...
# 41233  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 41234  Four Points by Sheraton Bengaluru, 43/3, White...
# 41235  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 41236  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# 2                                        San Churro Cafe          True
# 3                                  Addhuri Udupi Bhojana         False
# 4                                          Grand Village         False
# ...                                                  ...           ...
# 41232                         The Farm House Bar N Grill         False
# 41233                                            Bhagini         False
# 41234  Best Brews - Four Points By Sheraton Bengaluru...         False
# 41235  Chime - Sheraton Grand Bengaluru Whitefield Ho...         False
# 41236                       The Nest - The Den Bengaluru         False
#
#        book_table  rate  votes                    location  \
# 0            True   4.1    775                Banashankari
# 1           False   4.1    787                Banashankari
# 2           False   3.8    918                Banashankari
# 3           False   3.7     88                Banashankari
# 4           False   3.8    166                Basavanagudi
# ...           ...   ...    ...                         ...
# 41232       False   3.7     34                  Whitefield
# 41233       False   2.5     81                  Whitefield
# 41234       False   3.6     27                  Whitefield
# 41235        True   4.3    236  ITPL Main Road, Whitefield
# 41236       False   3.4     13  ITPL Main Road, Whitefield
#
#                  rest_type                                     cuisines  \
# 0            Casual Dining               North Indian, Mughlai, Chinese
# 1            Casual Dining                  Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                       Cafe, Mexican, Italian
# 3              Quick Bites                   South Indian, North Indian
# 4            Casual Dining                     North Indian, Rajasthani
# ...                    ...                                          ...
# 41232   Casual Dining, Bar                    North Indian, Continental
# 41233   Casual Dining, Bar  Andhra, South Indian, Chinese, North Indian
# 41234                  Bar                                  Continental
# 41235                  Bar                                  Finger Food
# 41236   Bar, Casual Dining       Finger Food, North Indian, Continental
#
#         cost                                       reviews_list menu_item  \
# 0      800.0  rated 40 ratedn beautiful place dine inthe int...        []
# 1      800.0  rated 40 ratedn dinner family turned good choo...        []
# 2      800.0  rated 30 ratedn ambience good enough pocket fr...        []
# 3      300.0  rated 40 ratedn great food proper karnataka st...        []
# 4      600.0  rated 40 ratedn good restaurant neighbourhood ...        []
# ...      ...                                                ...       ...
# 41232  800.0  rated 40 ratedn ambience big spacious lawn use...        []
# 41233  800.0  rated 40 ratedn fine place chill office hours ...        []
# 41234    1.5  rated 50 ratedn food service incomparably exce...        []
# 41235    2.5  rated 40 ratedn nice friendly place staff awes...        []
# 41236    1.5  rated 50 ratedn great ambience looking nice go...        []
#
#                 type          city  Mean Rating
# 0             Buffet  Banashankari         3.99
# 1             Buffet  Banashankari         3.97
# 2             Buffet  Banashankari         3.58
# 3             Buffet  Banashankari         3.45
# 4             Buffet  Banashankari         3.58
# ...              ...           ...          ...
# 41232  Pubs and bars    Whitefield         3.45
# 41233  Pubs and bars    Whitefield         1.62
# 41234  Pubs and bars    Whitefield         3.32
# 41235  Pubs and bars    Whitefield         4.23
# 41236  Pubs and bars    Whitefield         3.06
#
# [41237 rows x 15 columns]

# %%
from nltk.corpus import stopwords
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    """custom function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

zomato["reviews_list"] = zomato["reviews_list"].apply(lambda text: remove_stopwords(text))

# %%
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 41232  136, SAP Labs India, KIADB Export Promotion In...
# 41233  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 41234  Four Points by Sheraton Bengaluru, 43/3, White...
# 41235  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 41236  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# 2                                        San Churro Cafe          True
# 3                                  Addhuri Udupi Bhojana         False
# 4                                          Grand Village         False
# ...                                                  ...           ...
# 41232                         The Farm House Bar N Grill         False
# 41233                                            Bhagini         False
# 41234  Best Brews - Four Points By Sheraton Bengaluru...         False
# 41235  Chime - Sheraton Grand Bengaluru Whitefield Ho...         False
# 41236                       The Nest - The Den Bengaluru         False
#
#        book_table  rate  votes                    location  \
# 0            True   4.1    775                Banashankari
# 1           False   4.1    787                Banashankari
# 2           False   3.8    918                Banashankari
# 3           False   3.7     88                Banashankari
# 4           False   3.8    166                Basavanagudi
# ...           ...   ...    ...                         ...
# 41232       False   3.7     34                  Whitefield
# 41233       False   2.5     81                  Whitefield
# 41234       False   3.6     27                  Whitefield
# 41235        True   4.3    236  ITPL Main Road, Whitefield
# 41236       False   3.4     13  ITPL Main Road, Whitefield
#
#                  rest_type                                     cuisines  \
# 0            Casual Dining               North Indian, Mughlai, Chinese
# 1            Casual Dining                  Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                       Cafe, Mexican, Italian
# 3              Quick Bites                   South Indian, North Indian
# 4            Casual Dining                     North Indian, Rajasthani
# ...                    ...                                          ...
# 41232   Casual Dining, Bar                    North Indian, Continental
# 41233   Casual Dining, Bar  Andhra, South Indian, Chinese, North Indian
# 41234                  Bar                                  Continental
# 41235                  Bar                                  Finger Food
# 41236   Bar, Casual Dining       Finger Food, North Indian, Continental
#
#         cost                                       reviews_list menu_item  \
# 0      800.0  rated 40 ratedn beautiful place dine inthe int...        []
# 1      800.0  rated 40 ratedn dinner family turned good choo...        []
# 2      800.0  rated 30 ratedn ambience good enough pocket fr...        []
# 3      300.0  rated 40 ratedn great food proper karnataka st...        []
# 4      600.0  rated 40 ratedn good restaurant neighbourhood ...        []
# ...      ...                                                ...       ...
# 41232  800.0  rated 40 ratedn ambience big spacious lawn use...        []
# 41233  800.0  rated 40 ratedn fine place chill office hours ...        []
# 41234    1.5  rated 50 ratedn food service incomparably exce...        []
# 41235    2.5  rated 40 ratedn nice friendly place staff awes...        []
# 41236    1.5  rated 50 ratedn great ambience looking nice go...        []
#
#                 type          city  Mean Rating
# 0             Buffet  Banashankari         3.99
# 1             Buffet  Banashankari         3.97
# 2             Buffet  Banashankari         3.58
# 3             Buffet  Banashankari         3.45
# 4             Buffet  Banashankari         3.58
# ...              ...           ...          ...
# 41232  Pubs and bars    Whitefield         3.45
# 41233  Pubs and bars    Whitefield         1.62
# 41234  Pubs and bars    Whitefield         3.32
# 41235  Pubs and bars    Whitefield         4.23
# 41236  Pubs and bars    Whitefield         3.06
#
# [41237 rows x 15 columns]

# %%
def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)

zomato["reviews_list"] = zomato["reviews_list"].apply(lambda text: remove_urls(text))

zomato[['reviews_list', 'cuisines']].sample(5)
# Out:
#                                             reviews_list  \
# 20644  rated 30 ratedn visited place new menu like ot...
# 24313  rated 50 ratedn one friends suggested place hu...
# 6421   rated 20 ratedn usually order chinese kim chi ...
# 12546  rated 50 ratedn biryani kebab one best ive mus...
# 5670   rated 50 ratedn service 55nfood 55nambiance 55...
#
#                              cuisines
# 20644  North Indian, Mughlai, Chinese
# 24313                       Fast Food
# 6421   Chinese, North Indian, Biryani
# 12546           North Indian, Chinese
# 5670             Pizza, Cafe, Italian

# %%
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 41232  136, SAP Labs India, KIADB Export Promotion In...
# 41233  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 41234  Four Points by Sheraton Bengaluru, 43/3, White...
# 41235  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 41236  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# 2                                        San Churro Cafe          True
# 3                                  Addhuri Udupi Bhojana         False
# 4                                          Grand Village         False
# ...                                                  ...           ...
# 41232                         The Farm House Bar N Grill         False
# 41233                                            Bhagini         False
# 41234  Best Brews - Four Points By Sheraton Bengaluru...         False
# 41235  Chime - Sheraton Grand Bengaluru Whitefield Ho...         False
# 41236                       The Nest - The Den Bengaluru         False
#
#        book_table  rate  votes                    location  \
# 0            True   4.1    775                Banashankari
# 1           False   4.1    787                Banashankari
# 2           False   3.8    918                Banashankari
# 3           False   3.7     88                Banashankari
# 4           False   3.8    166                Basavanagudi
# ...           ...   ...    ...                         ...
# 41232       False   3.7     34                  Whitefield
# 41233       False   2.5     81                  Whitefield
# 41234       False   3.6     27                  Whitefield
# 41235        True   4.3    236  ITPL Main Road, Whitefield
# 41236       False   3.4     13  ITPL Main Road, Whitefield
#
#                  rest_type                                     cuisines  \
# 0            Casual Dining               North Indian, Mughlai, Chinese
# 1            Casual Dining                  Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                       Cafe, Mexican, Italian
# 3              Quick Bites                   South Indian, North Indian
# 4            Casual Dining                     North Indian, Rajasthani
# ...                    ...                                          ...
# 41232   Casual Dining, Bar                    North Indian, Continental
# 41233   Casual Dining, Bar  Andhra, South Indian, Chinese, North Indian
# 41234                  Bar                                  Continental
# 41235                  Bar                                  Finger Food
# 41236   Bar, Casual Dining       Finger Food, North Indian, Continental
#
#         cost                                       reviews_list menu_item  \
# 0      800.0  rated 40 ratedn beautiful place dine inthe int...        []
# 1      800.0  rated 40 ratedn dinner family turned good choo...        []
# 2      800.0  rated 30 ratedn ambience good enough pocket fr...        []
# 3      300.0  rated 40 ratedn great food proper karnataka st...        []
# 4      600.0  rated 40 ratedn good restaurant neighbourhood ...        []
# ...      ...                                                ...       ...
# 41232  800.0  rated 40 ratedn ambience big spacious lawn use...        []
# 41233  800.0  rated 40 ratedn fine place chill office hours ...        []
# 41234    1.5  rated 50 ratedn food service incomparably exce...        []
# 41235    2.5  rated 40 ratedn nice friendly place staff awes...        []
# 41236    1.5  rated 50 ratedn great ambience looking nice go...        []
#
#                 type          city  Mean Rating
# 0             Buffet  Banashankari         3.99
# 1             Buffet  Banashankari         3.97
# 2             Buffet  Banashankari         3.58
# 3             Buffet  Banashankari         3.45
# 4             Buffet  Banashankari         3.58
# ...              ...           ...          ...
# 41232  Pubs and bars    Whitefield         3.45
# 41233  Pubs and bars    Whitefield         1.62
# 41234  Pubs and bars    Whitefield         3.32
# 41235  Pubs and bars    Whitefield         4.23
# 41236  Pubs and bars    Whitefield         3.06
#
# [41237 rows x 15 columns]

# %%
restaurant_names = list(zomato['name'].unique())
def get_top_words(column, top_nu_of_words, nu_of_word):
    vec = CountVectorizer(ngram_range= nu_of_word, stop_words='english')
    bag_of_words = vec.fit_transform(column)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:top_nu_of_words]
    
zomato=zomato.drop(['address','rest_type', 'type', 'menu_item', 'votes'],axis=1)

# %%
zomato
# Out:
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# 2                                        San Churro Cafe          True
# 3                                  Addhuri Udupi Bhojana         False
# 4                                          Grand Village         False
# ...                                                  ...           ...
# 41232                         The Farm House Bar N Grill         False
# 41233                                            Bhagini         False
# 41234  Best Brews - Four Points By Sheraton Bengaluru...         False
# 41235  Chime - Sheraton Grand Bengaluru Whitefield Ho...         False
# 41236                       The Nest - The Den Bengaluru         False
#
#        book_table  rate                    location  \
# 0            True   4.1                Banashankari
# 1           False   4.1                Banashankari
# 2           False   3.8                Banashankari
# 3           False   3.7                Banashankari
# 4           False   3.8                Basavanagudi
# ...           ...   ...                         ...
# 41232       False   3.7                  Whitefield
# 41233       False   2.5                  Whitefield
# 41234       False   3.6                  Whitefield
# 41235        True   4.3  ITPL Main Road, Whitefield
# 41236       False   3.4  ITPL Main Road, Whitefield
#
#                                           cuisines   cost  \
# 0                   North Indian, Mughlai, Chinese  800.0
# 1                      Chinese, North Indian, Thai  800.0
# 2                           Cafe, Mexican, Italian  800.0
# 3                       South Indian, North Indian  300.0
# 4                         North Indian, Rajasthani  600.0
# ...                                            ...    ...
# 41232                    North Indian, Continental  800.0
# 41233  Andhra, South Indian, Chinese, North Indian  800.0
# 41234                                  Continental    1.5
# 41235                                  Finger Food    2.5
# 41236       Finger Food, North Indian, Continental    1.5
#
#                                             reviews_list          city  \
# 0      rated 40 ratedn beautiful place dine inthe int...  Banashankari
# 1      rated 40 ratedn dinner family turned good choo...  Banashankari
# 2      rated 30 ratedn ambience good enough pocket fr...  Banashankari
# 3      rated 40 ratedn great food proper karnataka st...  Banashankari
# 4      rated 40 ratedn good restaurant neighbourhood ...  Banashankari
# ...                                                  ...           ...
# 41232  rated 40 ratedn ambience big spacious lawn use...    Whitefield
# 41233  rated 40 ratedn fine place chill office hours ...    Whitefield
# 41234  rated 50 ratedn food service incomparably exce...    Whitefield
# 41235  rated 40 ratedn nice friendly place staff awes...    Whitefield
# 41236  rated 50 ratedn great ambience looking nice go...    Whitefield
#
#        Mean Rating
# 0             3.99
# 1             3.97
# 2             3.58
# 3             3.45
# 4             3.58
# ...            ...
# 41232         3.45
# 41233         1.62
# 41234         3.32
# 41235         4.23
# 41236         3.06
#
# [41237 rows x 10 columns]

# %%
import pandas
df_percent = zomato.sample(frac=0.5)
df_percent.set_index('name', inplace=True)
df_percent
# Out:
#                        online_order  book_table  rate               location  \
# name
# Caferia                        True       False   3.3            Frazer Town
# Darbar                        False       False   3.0           Banashankari
# Domino'S Pizza                 True       False   3.0            Brookefield
# Aramane Donne Biryani          True       False   3.5           Banashankari
# Skytouch Le Cafe               True       False   3.7               JP Nagar
# ...                             ...         ...   ...                    ...
# Fiero! Pizzeria                True       False   4.0  Koramangala 6th Block
# Chaat Street                   True       False   3.9  Koramangala 6th Block
# Owl'S Kitchen                 False       False   3.1                    BTM
# Grills & Rolls                 True       False   2.5               JP Nagar
# Burrito Boys                   True       False   3.0      Bannerghatta Road
#
#                                                               cuisines   cost  \
# name
# Caferia                                         Fast Food, Street Food  200.0
# Darbar                                           North Indian, Chinese  800.0
# Domino'S Pizza                                        Pizza, Fast Food  800.0
# Aramane Donne Biryani                                          Biryani  200.0
# Skytouch Le Cafe                               Cafe, Italian, Desserts  700.0
# ...                                                                ...    ...
# Fiero! Pizzeria                              Italian, Fast Food, Pizza  400.0
# Chaat Street                                 Street Food, North Indian  250.0
# Owl'S Kitchen                                    North Indian, Chinese  500.0
# Grills & Rolls         North Indian, Chinese, Fast Food, Rolls, Juices  400.0
# Burrito Boys                                          Mexican, Tex-Mex  400.0
#
#                                                             reviews_list  \
# name
# Caferia                rated 50 ratedn tender coconut milk shake sand...
# Darbar                 rated 30 ratedn visit place often friends budg...
# Domino'S Pizza         rated 40 ratedn comes pizza cravings go place ...
# Aramane Donne Biryani  rated 10 ratedn chicken kabab good quantity le...
# Skytouch Le Cafe       rated 10 ratedn thing worse quality food way p...
# ...                                                                  ...
# Fiero! Pizzeria        rated 50 ratedn amazing place thinking checkin...
# Chaat Street           rated 40 ratedn completely north indian loved ...
# Owl'S Kitchen          rated 10 ratedn pathetic service place order i...
# Grills & Rolls         rated 30 ratedn literally place u get u pay ma...
# Burrito Boys           rated 10 ratedn ordered vegetarian burrito lea...
#
#                                         city  Mean Rating
# name
# Caferia                          Frazer Town         2.94
# Darbar                          Basavanagudi         2.55
# Domino'S Pizza                   Brookefield         3.27
# Aramane Donne Biryani           Banashankari         3.00
# Skytouch Le Cafe                    JP Nagar         3.45
# ...                                      ...          ...
# Fiero! Pizzeria        Koramangala 4th Block         3.84
# Chaat Street           Koramangala 5th Block         3.85
# Owl'S Kitchen                            BTM         2.68
# Grills & Rolls                           BTM         1.90
# Burrito Boys               Bannerghatta Road         2.43
#
# [20618 rows x 9 columns]

# %%
indices = pd.Series(df_percent.index)
indices
# Out:
# 0                      Caferia
# 1                       Darbar
# 2               Domino'S Pizza
# 3        Aramane Donne Biryani
# 4             Skytouch Le Cafe
#                  ...
# 20613          Fiero! Pizzeria
# 20614             Chaat Street
# 20615            Owl'S Kitchen
# 20616           Grills & Rolls
# 20617             Burrito Boys
# Name: name, Length: 20618, dtype: object
